# %%
import fastf1

session = fastf1.get_session(2019, 'Monza', 'Q')
session.load(telemetry = False, laps = False, weather = False)
vettel = session.get_driver('VET')
print(f'Pronto {vettel.FirstName}?')
# Out:
# req         WARNING
#
# DEFAULT CACHE ENABLED!
# 	Cache directory: C:\Users\abdul\AppData\Local\Temp\fastf1.
# 	Size: 458.06 MB
# core           INFO 	Loading data for Italian Grand Prix - Qualifying [v3.1.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '44', '77', '5', '3', '27', '55', '23', '18', '7', '99', '20', '26', '4', '10', '8', '11', '63', '88', '33']
# Pronto Sebastian?

# %%
import matplotlib.pyplot as plt
import fastf1.plotting

fastf1.plotting.setup_mpl()
session = fastf1.get_session(2019, 'Monza', 'Q')
session.load()

fast_leclerc = session.laps.pick_driver('LEC').pick_fastest()
lec_car_data = fast_leclerc.get_car_data()
t = lec_car_data['Time']
vCar = lec_car_data['Speed']

# plotting
fig, ax = plt.subplots()
ax.plot(t, vCar, label = "Fast")
ax.set_xlabel('Time [s]')
ax.set_ylabel('Speed [km/h]')
ax.set_title('Leclerc - Monza 2019 Q')
ax.legend()
plt.show()
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Qualifying [v3.1.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '44', '77', '5', '3', '27', '55', '23', '18', '7', '99', '20', '26', '4', '10', '8', '11', '63', '88', '33']

# %%
# Loading a session or an event

session = fastf1.get_session(2021, 7, 'Q')
print(session.name)
print(session.date)
print(session.event)
print(session.event.EventName)
print(session.event.EventDate)
# Out:
# Qualifying
# 2021-06-19 13:00:00
# RoundNumber                                                     7
# Country                                                    France
# Location                                             Le Castellet
# OfficialEventName    FORMULA 1 EMIRATES GRAND PRIX DE FRANCE 2021
# EventDate                                     2021-06-20 00:00:00
# EventName                                       French Grand Prix
# EventFormat                                          conventional
# Session1                                               Practice 1
# Session1Date                            2021-06-18 11:30:00+02:00
# Session1DateUtc                               2021-06-18 09:30:00
# Session2                                               Practice 2
# Session2Date                            2021-06-18 15:00:00+02:00
# Session2DateUtc                               2021-06-18 13:00:00
# Session3                                               Practice 3
# Session3Date                            2021-06-19 12:00:00+02:00
# Session3DateUtc                               2021-06-19 10:00:00
# Session4                                               Qualifying
# Session4Date                            2021-06-19 15:00:00+02:00
# Session4DateUtc                               2021-06-19 13:00:00
# Session5                                                     Race
# Session5Date                            2021-06-20 15:00:00+02:00
# Session5DateUtc                               2021-06-20 13:00:00
# F1ApiSupport                                                 True
# Name: 7, dtype: object
# French Grand Prix
# 2021-06-20 00:00:00

# %%
event = fastf1.get_event(2021, 7)
print(event)
session = event.get_race()
session.name
# Out:
# RoundNumber                                                     7
# Country                                                    France
# Location                                             Le Castellet
# OfficialEventName    FORMULA 1 EMIRATES GRAND PRIX DE FRANCE 2021
# EventDate                                     2021-06-20 00:00:00
# EventName                                       French Grand Prix
# EventFormat                                          conventional
# Session1                                               Practice 1
# Session1Date                            2021-06-18 11:30:00+02:00
# Session1DateUtc                               2021-06-18 09:30:00
# Session2                                               Practice 2
# Session2Date                            2021-06-18 15:00:00+02:00
# Session2DateUtc                               2021-06-18 13:00:00
# Session3                                               Practice 3
# Session3Date                            2021-06-19 12:00:00+02:00
# Session3DateUtc                               2021-06-19 10:00:00
# Session4                                               Qualifying
# Session4Date                            2021-06-19 15:00:00+02:00
# Session4DateUtc                               2021-06-19 13:00:00
# Session5                                                     Race
# Session5Date                            2021-06-20 15:00:00+02:00
# Session5DateUtc                               2021-06-20 13:00:00
# F1ApiSupport                                                 True
# Name: 7, dtype: object
# 'Race'

# %%
event = fastf1.get_event(2021, 'French Grand Prix')
print(event.EventName)
event = fastf1.get_event(2021, 'spain')
print(event.EventName)
# Out:
# French Grand Prix
# Spanish Grand Prix

# %%
schedule = fastf1.get_event_schedule(2021)
schedule.columns
# Out:
# Index(['RoundNumber', 'Country', 'Location', 'OfficialEventName', 'EventDate',
#        'EventName', 'EventFormat', 'Session1', 'Session1Date',
#        'Session1DateUtc', 'Session2', 'Session2Date', 'Session2DateUtc',
#        'Session3', 'Session3Date', 'Session3DateUtc', 'Session4',
#        'Session4Date', 'Session4DateUtc', 'Session5', 'Session5Date',
#        'Session5DateUtc', 'F1ApiSupport'],
#       dtype='object')

# %%
session = fastf1.get_session(2021, 'Monaco', 'Q')
session.load()
session.results
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.1.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 47
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '33', '77', '55', '4', '10', '44', '5', '11', '99', '31', '3', '18', '7', '63', '22', '14', '6', '9', '47']
#    DriverNumber BroadcastName Abbreviation        DriverId           TeamName  \
# 16           16     C LECLERC          LEC         leclerc            Ferrari
# 33           33  M VERSTAPPEN          VER  max_verstappen    Red Bull Racing
# 77           77      V BOTTAS          BOT          bottas           Mercedes
# 55           55       C SAINZ          SAI           sainz            Ferrari
# 4             4      L NORRIS          NOR          norris            McLaren
# 10           10       P GASLY          GAS           gasly         AlphaTauri
# 44           44    L HAMILTON          HAM        hamilton           Mercedes
# 5             5      S VETTEL          VET          vettel       Aston Martin
# 11           11       S PEREZ          PER           perez    Red Bull Racing
# 99           99  A GIOVINAZZI          GIO      giovinazzi  Alfa Romeo Racing
# 31           31        E OCON          OCO            ocon             Alpine
# 3             3   D RICCIARDO          RIC       ricciardo            McLaren
# 18           18      L STROLL          STR          stroll       Aston Martin
# 7             7   K RAIKKONEN          RAI       raikkonen  Alfa Romeo Racing
# 63           63     G RUSSELL          RUS         russell           Williams
# 22           22     Y TSUNODA          TSU         tsunoda         AlphaTauri
# 14           14      F ALONSO          ALO          alonso             Alpine
# 6             6      N LATIFI          LAT          latifi           Williams
# 9             9     N MAZEPIN          MAZ         mazepin       Haas F1 Team
# 47           47  M SCHUMACHER          MSC             nan       Haas F1 Team
#
#    TeamColor        TeamId  FirstName    LastName            FullName  ...  \
# 16    DC0004       ferrari    Charles     Leclerc     Charles Leclerc  ...
# 33    0600EF      red_bull        Max  Verstappen      Max Verstappen  ...
# 77    00D2BE      mercedes   Valtteri      Bottas     Valtteri Bottas  ...
# 55    DC0004       ferrari     Carlos       Sainz        Carlos Sainz  ...
# 4     FF9800       mclaren      Lando      Norris        Lando Norris  ...
# 10    2B4562    alphatauri     Pierre       Gasly        Pierre Gasly  ...
# 44    00D2BE      mercedes      Lewis    Hamilton      Lewis Hamilton  ...
# 5     006F62  aston_martin  Sebastian      Vettel    Sebastian Vettel  ...
# 11    0600EF      red_bull     Sergio       Perez        Sergio Perez  ...
# 99    900000          alfa    Antonio  Giovinazzi  Antonio Giovinazzi  ...
# 31    0090FF        alpine    Esteban        Ocon        Esteban Ocon  ...
# 3     FF9800       mclaren     Daniel   Ricciardo    Daniel Ricciardo  ...
# 18    006F62  aston_martin      Lance      Stroll        Lance Stroll  ...
# 7     900000          alfa       Kimi   Räikkönen      Kimi Räikkönen  ...
# 63    005AFF      williams     George     Russell      George Russell  ...
# 22    2B4562    alphatauri       Yuki     Tsunoda        Yuki Tsunoda  ...
# 14    0090FF        alpine   Fernando      Alonso     Fernando Alonso  ...
# 6     005AFF      williams   Nicholas      Latifi     Nicholas Latifi  ...
# 9     FFFFFF          haas     Nikita     Mazepin      Nikita Mazepin  ...
# 47    FFFFFF           nan       Mick  Schumacher     Mick Schumacher  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  \
# 16                  1.0                              NaN
# 33                  2.0                              NaN
# 77                  3.0                              NaN
# 55                  4.0                              NaN
# 4                   5.0                              NaN
# 10                  6.0                              NaN
# 44                  7.0                              NaN
# 5                   8.0                              NaN
# 11                  9.0                              NaN
# 99                 10.0                              NaN
# 31                 11.0                              NaN
# 3                  12.0                              NaN
# 18                 13.0                              NaN
# 7                  14.0                              NaN
# 63                 15.0                              NaN
# 22                 16.0                              NaN
# 14                 17.0                              NaN
# 6                  18.0                              NaN
# 9                  19.0                              NaN
# 47                  NaN                              NaN
#
#                        Q1                     Q2                     Q3 Time  \
# 16 0 days 00:01:11.113000 0 days 00:01:10.597000 0 days 00:01:10.346000  NaT
# 33 0 days 00:01:11.124000 0 days 00:01:10.650000 0 days 00:01:10.576000  NaT
# 77 0 days 00:01:10.938000 0 days 00:01:10.695000 0 days 00:01:10.601000  NaT
# 55 0 days 00:01:11.324000 0 days 00:01:10.806000 0 days 00:01:10.611000  NaT
# 4  0 days 00:01:11.321000 0 days 00:01:11.031000 0 days 00:01:10.620000  NaT
# 10 0 days 00:01:11.560000 0 days 00:01:11.179000 0 days 00:01:10.900000  NaT
# 44 0 days 00:01:11.622000 0 days 00:01:11.116000 0 days 00:01:11.095000  NaT
# 5  0 days 00:01:12.078000 0 days 00:01:11.309000 0 days 00:01:11.419000  NaT
# 11 0 days 00:01:11.644000 0 days 00:01:11.019000 0 days 00:01:11.573000  NaT
# 99 0 days 00:01:11.658000 0 days 00:01:11.409000 0 days 00:01:11.779000  NaT
# 31 0 days 00:01:11.740000 0 days 00:01:11.486000                    NaT  NaT
# 3  0 days 00:01:11.747000 0 days 00:01:11.598000                    NaT  NaT
# 18 0 days 00:01:11.979000 0 days 00:01:11.600000                    NaT  NaT
# 7  0 days 00:01:11.899000 0 days 00:01:11.642000                    NaT  NaT
# 63 0 days 00:01:12.016000 0 days 00:01:11.830000                    NaT  NaT
# 22 0 days 00:01:12.096000                    NaT                    NaT  NaT
# 14 0 days 00:01:12.205000                    NaT                    NaT  NaT
# 6  0 days 00:01:12.366000                    NaT                    NaT  NaT
# 9  0 days 00:01:12.958000                    NaT                    NaT  NaT
# 47                    NaT                    NaT                    NaT  NaT
#
#    Status Points
# 16           NaN
# 33           NaN
# 77           NaN
# 55           NaN
# 4            NaN
# 10           NaN
# 44           NaN
# 5            NaN
# 11           NaN
# 99           NaN
# 31           NaN
# 3            NaN
# 18           NaN
# 7            NaN
# 63           NaN
# 22           NaN
# 14           NaN
# 6            NaN
# 9            NaN
# 47           NaN
#
# [20 rows x 21 columns]

# %%
session.results.iloc[0:10].loc[:, ['Abbreviation', 'Q3']]
# Out:
#    Abbreviation                     Q3
# 16          LEC 0 days 00:01:10.346000
# 33          VER 0 days 00:01:10.576000
# 77          BOT 0 days 00:01:10.601000
# 55          SAI 0 days 00:01:10.611000
# 4           NOR 0 days 00:01:10.620000
# 10          GAS 0 days 00:01:10.900000
# 44          HAM 0 days 00:01:11.095000
# 5           VET 0 days 00:01:11.419000
# 11          PER 0 days 00:01:11.573000
# 99          GIO 0 days 00:01:11.779000

# %%
session = fastf1.get_session(2021, 'French Grand Prix', 'Q')
session.load()
session.laps
# Out:
# core           INFO 	Loading data for French Grand Prix - Qualifying [v3.1.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '11', '55', '10', '16', '4', '14', '3', '31', '5', '99', '63', '47', '6', '7', '9', '18', '22']
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:17:35.479000    GAS           10                    NaT
# 1   0 days 00:27:42.702000    GAS           10                    NaT
# 2   0 days 00:30:15.038000    GAS           10                    NaT
# 3   0 days 00:31:46.936000    GAS           10 0 days 00:01:31.898000
# 4   0 days 00:34:20.695000    GAS           10                    NaT
# ..                     ...    ...          ...                    ...
# 265 0 days 00:54:22.881000    GIO           99 0 days 00:01:32.182000
# 266 0 days 01:00:32.369000    GIO           99                    NaT
# 267 0 days 01:03:24.940000    GIO           99                    NaT
# 268 0 days 01:04:56.753000    GIO           99 0 days 00:01:31.813000
# 269 0 days 01:06:42.885000    GIO           99                    NaT
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# 0          1.0    1.0 0 days 00:14:47.810000                    NaT
# 1          2.0    1.0                    NaT 0 days 00:19:40.614000
# 2          3.0    2.0 0 days 00:27:42.702000                    NaT
# 3          4.0    2.0                    NaT                    NaT
# 4          5.0    2.0                    NaT                    NaT
# ..         ...    ...                    ...                    ...
# 265        9.0    4.0                    NaT                    NaT
# 266       10.0    4.0                    NaT 0 days 00:56:04.344000
# 267       11.0    5.0 0 days 01:00:32.260000                    NaT
# 268       12.0    5.0                    NaT                    NaT
# 269       13.0    5.0                    NaT 0 days 01:06:42.885000
#
#                Sector1Time            Sector2Time  ... FreshTyre  \
# 0   0 days 00:00:48.895000 0 days 00:00:46.957000  ...      True
# 1   0 days 00:00:23.040000                    NaT  ...      True
# 2   0 days 00:00:43.813000 0 days 00:00:40.047000  ...     False
# 3   0 days 00:00:22.843000 0 days 00:00:27.881000  ...     False
# 4   0 days 00:00:37.442000 0 days 00:00:47.382000  ...     False
# ..                     ...                    ...  ...       ...
# 265 0 days 00:00:23.146000 0 days 00:00:27.947000  ...      True
# 266 0 days 00:00:26.297000 0 days 00:00:33.082000  ...      True
# 267 0 days 00:00:49.673000 0 days 00:00:41.499000  ...      True
# 268 0 days 00:00:22.846000 0 days 00:00:27.868000  ...      True
# 269 0 days 00:00:26.501000 0 days 00:00:36.969000  ...      True
#
#                   Team           LapStartTime            LapStartDate  \
# 0           AlphaTauri 0 days 00:14:47.810000 2021-06-19 13:00:15.013
# 1           AlphaTauri 0 days 00:17:35.479000 2021-06-19 13:03:02.682
# 2           AlphaTauri 0 days 00:27:42.702000 2021-06-19 13:13:09.905
# 3           AlphaTauri 0 days 00:30:15.038000 2021-06-19 13:15:42.241
# 4           AlphaTauri 0 days 00:31:46.936000 2021-06-19 13:17:14.139
# ..                 ...                    ...                     ...
# 265  Alfa Romeo Racing 0 days 00:52:50.699000 2021-06-19 13:38:17.902
# 266  Alfa Romeo Racing 0 days 00:54:22.881000 2021-06-19 13:39:50.084
# 267  Alfa Romeo Racing 0 days 01:00:32.369000 2021-06-19 13:45:59.572
# 268  Alfa Romeo Racing 0 days 01:03:24.940000 2021-06-19 13:48:52.143
# 269  Alfa Romeo Racing 0 days 01:04:56.753000 2021-06-19 13:50:23.956
#
#      TrackStatus  Position  Deleted  DeletedReason FastF1Generated IsAccurate
# 0              1       NaN    False                          False      False
# 1             25       NaN    False                          False      False
# 2              1       NaN    False                          False      False
# 3              1       NaN    False                          False       True
# 4              1       NaN    False                          False      False
# ..           ...       ...      ...            ...             ...        ...
# 265            1       NaN    False                          False       True
# 266            1       NaN    False                          False      False
# 267            1       NaN    False                          False      False
# 268            1       NaN    False                          False       True
# 269            1       NaN    False                          False      False
#
# [270 rows x 31 columns]

# %%
session.laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
fastest_lap = session.laps.pick_fastest()
print(fastest_lap.LapTime)
print(fastest_lap.Driver)
# Out:
# 0 days 00:01:29.990000
# VER
